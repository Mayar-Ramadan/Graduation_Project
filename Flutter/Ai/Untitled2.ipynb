# %%
from fastapi import FastAPI
from catboost import CatBoostClassifier
import numpy as np

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\elmohandes\anaconda3\lib\site-packages (1.2.10)
# Requirement already satisfied: graphviz in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas<4.0,>=0.24 in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\elmohandes\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elmohandes\anaconda3\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elmohandes\anaconda3\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elmohandes\anaconda3\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\elmohandes\anaconda3\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\elmohandes\anaconda3\lib\site-packages (from plotly->catboost) (8.2.3)

# %%
app = FastAPI()

# %%
# تحميل الموديل اللي انت خزّنته
model = CatBoostClassifier()
model.load_model("CatBoost_WaterConsumption.cbm")  # أو .pkl حسب عندك

@app.post("/predict")
def predict(data: dict):
    x = np.array(data["features"]).reshape(1,-1)
    prediction = model.predict(x)
    return {"prediction": prediction.tolist()}

@app.get("/")
def home():
    return {"message": "API working"}

# %%
 pip install uvicorn
# Out:
# Requirement already satisfied: uvicorn in c:\users\elmohandes\anaconda3\lib\site-packages (0.44.0)
# Requirement already satisfied: click>=7.0 in c:\users\elmohandes\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\elmohandes\anaconda3\lib\site-packages (from uvicorn) (0.9.0)
# Requirement already satisfied: colorama in c:\users\elmohandes\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
